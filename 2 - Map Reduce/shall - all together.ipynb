# %%
# !hadoop fs -ls s3://afeka-big-data-course/Data
# Out:
# Found 4 items
# drwxrwxrwx   - hadoop hadoop          0 1970-01-01 00:00 s3://afeka-big-data-course/Data/Encyclopaedia Britannica
# drwxrwxrwx   - hadoop hadoop          0 1970-01-01 00:00 s3://afeka-big-data-course/Data/Gutenberg
# drwxrwxrwx   - hadoop hadoop          0 1970-01-01 00:00 s3://afeka-big-data-course/Data/Wikipedia
# -rw-rw-rw-   1 hadoop hadoop    5444268 2020-08-14 08:40 s3://afeka-big-data-course/Data/books.json

# %%
mkdir data

# %%
cd data
# Out:
# /home/hadoop/data

# %%
ls

# %%
# !hadoop distcp s3://afeka-big-data-course/Data/Gutenberg .
# Out:
# 21/04/24 15:07:49 INFO tools.OptionsParser: parseChunkSize: blocksperchunk false
# 21/04/24 15:07:50 INFO tools.DistCp: Input Options: DistCpOptions{atomicCommit=false, syncFolder=false, deleteMissing=false, ignoreFailures=false, overwrite=false, append=false, useDiff=false, useRdiff=false, fromSnapshot=null, toSnapshot=null, skipCRC=false, blocking=true, numListstatusThreads=0, maxMaps=20, mapBandwidth=100, sslConfigurationFile='null', copyStrategy='uniformsize', preserveStatus=[], preserveRawXattrs=false, atomicWorkPath=null, logPath=null, sourceFileListing=null, sourcePaths=[s3://afeka-big-data-course/Data/Gutenberg], targetPath=, targetPathExists=true, filtersFile='null', blocksPerChunk=0, copyBufferSize=8192, verboseLog=false}
# 21/04/24 15:07:50 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# ...

# %%
# !hadoop fs -ls .
# Out:
# Found 2 items
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 14:55 Data
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 15:08 Gutenberg

# %%
cd ~
# Out:
# /home/hadoop

# %%
# !chmod ugo+x *.py

# %%
# !echo 'foo foo quux labs foo bar quux' | python3 ./mapper.py | sort -k1,1 | python3 ./reducer.py
# Out:
# bar 1
# foo 3
# labs 1
# quux 2

# %%
cd /home/hadoop
# Out:
# /home/hadoop

# %%
# !hadoop fs -ls
# Out:
# Found 2 items
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 14:55 Data
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 15:08 Gutenberg

# %%
# 1 slave - Gutenberg
# !time hadoop jar /usr/lib/hadoop-mapreduce/hadoop-streaming.jar -input Gutenberg/* -output resultGutenberg1 -mapper 'python mapper.py' -reducer 'python reducer.py' -file /home/hadoop/mapper.py  -file /home/hadoop/reducer.py
# Out:
# 21/04/24 15:12:04 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/home/hadoop/mapper.py, /home/hadoop/reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.10.1-amzn-1.jar] /tmp/streamjob5171896604303371424.jar tmpDir=null
# 21/04/24 15:12:06 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 15:12:06 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 15:12:06 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 15:12:06 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 15:12:07 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# ...

# %%
# !hadoop distcp s3://afeka-big-data-course/Data/Wikipedia .
# Out:
# 21/04/24 15:15:57 INFO tools.OptionsParser: parseChunkSize: blocksperchunk false
# 21/04/24 15:15:58 INFO tools.DistCp: Input Options: DistCpOptions{atomicCommit=false, syncFolder=false, deleteMissing=false, ignoreFailures=false, overwrite=false, append=false, useDiff=false, useRdiff=false, fromSnapshot=null, toSnapshot=null, skipCRC=false, blocking=true, numListstatusThreads=0, maxMaps=20, mapBandwidth=100, sslConfigurationFile='null', copyStrategy='uniformsize', preserveStatus=[], preserveRawXattrs=false, atomicWorkPath=null, logPath=null, sourceFileListing=null, sourcePaths=[s3://afeka-big-data-course/Data/Wikipedia], targetPath=, targetPathExists=true, filtersFile='null', blocksPerChunk=0, copyBufferSize=8192, verboseLog=false}
# 21/04/24 15:15:58 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# ...

# %%
# !hadoop fs -ls .
# Out:
# Found 4 items
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 14:55 Data
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 15:08 Gutenberg
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 15:20 Wikipedia
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 15:12 resultGutenberg1

# %%
cd ~
# Out:
# /home/hadoop

# %%
# 1 slave - Wikipedia
# !time hadoop jar /usr/lib/hadoop-mapreduce/hadoop-streaming.jar -input Wikipedia/* -output resultWiki1 -mapper 'python mapper.py' -reducer 'python reducer.py' -file /home/hadoop/mapper.py  -file /home/hadoop/reducer.py
# Out:
# 21/04/24 15:25:27 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/home/hadoop/mapper.py, /home/hadoop/reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.10.1-amzn-1.jar] /tmp/streamjob2004196275900883198.jar tmpDir=null
# 21/04/24 15:25:28 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 15:25:28 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 15:25:28 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 15:25:28 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 15:25:29 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# ...

# %%
# !hadoop distcp s3://afeka-big-data-course/Data/"Encyclopaedia Britannica" .
# Out:
# 21/04/24 15:57:46 INFO tools.OptionsParser: parseChunkSize: blocksperchunk false
# 21/04/24 15:57:47 INFO tools.DistCp: Input Options: DistCpOptions{atomicCommit=false, syncFolder=false, deleteMissing=false, ignoreFailures=false, overwrite=false, append=false, useDiff=false, useRdiff=false, fromSnapshot=null, toSnapshot=null, skipCRC=false, blocking=true, numListstatusThreads=0, maxMaps=20, mapBandwidth=100, sslConfigurationFile='null', copyStrategy='uniformsize', preserveStatus=[], preserveRawXattrs=false, atomicWorkPath=null, logPath=null, sourceFileListing=null, sourcePaths=[s3://afeka-big-data-course/Data/Encyclopaedia Britannica], targetPath=, targetPathExists=true, filtersFile='null', blocksPerChunk=0, copyBufferSize=8192, verboseLog=false}
# 21/04/24 15:57:47 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# ...

# %%
# !hadoop fs -ls .
# Out:
# Found 6 items
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 14:55 Data
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 16:01 Encyclopaedia Britannica
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 15:08 Gutenberg
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 15:20 Wikipedia
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 15:12 resultGutenberg1
# drwxr-xr-x   - hadoop hdfsadmingroup          0 2021-04-24 15:55 resultWiki1

# %%
cd ~
# Out:
# /home/hadoop

# %%
# 1 slave - Encyclopaedia Britannica
# !time hadoop jar /usr/lib/hadoop-mapreduce/hadoop-streaming.jar -input "Encyclopaedia Britannica"/* -output resultBritanica1again -mapper 'python mapper.py' -reducer 'python reducer.py' -file /home/hadoop/mapper.py  -file /home/hadoop/reducer.py
# Out:
# 21/04/24 16:03:41 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/home/hadoop/mapper.py, /home/hadoop/reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.10.1-amzn-1.jar] /tmp/streamjob8304798665633170839.jar tmpDir=null
# 21/04/24 16:03:46 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:03:46 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:03:46 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:03:46 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:03:48 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# ...

# %%
# 5 slave - Gutenberg
# !time hadoop jar /usr/lib/hadoop-mapreduce/hadoop-streaming.jar -input Gutenberg/* -output resultGutenberg5 -mapper 'python mapper.py' -reducer 'python reducer.py' -file /home/hadoop/mapper.py  -file /home/hadoop/reducer.py
# Out:
# 21/04/24 16:17:06 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/home/hadoop/mapper.py, /home/hadoop/reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.10.1-amzn-1.jar] /tmp/streamjob3584858312032356720.jar tmpDir=null
# 21/04/24 16:17:08 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:17:08 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:17:08 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:17:08 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:17:10 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# ...

# %%
# 5 slave - Encyclopaedia Britannica
# !time hadoop jar /usr/lib/hadoop-mapreduce/hadoop-streaming.jar -input "Encyclopaedia Britannica"/* -output resultBritanica5 -mapper 'python mapper.py' -reducer 'python reducer.py' -file /home/hadoop/mapper.py  -file /home/hadoop/reducer.py
# Out:
# 21/04/24 16:20:15 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/home/hadoop/mapper.py, /home/hadoop/reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.10.1-amzn-1.jar] /tmp/streamjob5698176367952566869.jar tmpDir=null
# 21/04/24 16:20:16 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:20:16 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:20:16 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:20:16 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:20:17 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# ...

# %%
# 5 slave - Wikipedia
# !time hadoop jar /usr/lib/hadoop-mapreduce/hadoop-streaming.jar -input Wikipedia/* -output resultWiki5 -mapper 'python mapper.py' -reducer 'python reducer.py' -file /home/hadoop/mapper.py  -file /home/hadoop/reducer.py
# Out:
# 21/04/24 16:23:10 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/home/hadoop/mapper.py, /home/hadoop/reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.10.1-amzn-1.jar] /tmp/streamjob9204869788392606366.jar tmpDir=null
# 21/04/24 16:23:11 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:23:11 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:23:11 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:23:11 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:23:13 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# ...

# %%
# 8 slave - Gutenberg
# !time hadoop jar /usr/lib/hadoop-mapreduce/hadoop-streaming.jar -input Gutenberg/* -output resultGutenberg8 -mapper 'python mapper.py' -reducer 'python reducer.py' -file /home/hadoop/mapper.py  -file /home/hadoop/reducer.py
# Out:
# 21/04/24 16:43:45 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/home/hadoop/mapper.py, /home/hadoop/reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.10.1-amzn-1.jar] /tmp/streamjob1365820000280959408.jar tmpDir=null
# 21/04/24 16:43:47 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:43:47 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:43:47 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:43:47 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:43:48 WARN hdfs.DataStreamer: Caught exception
# java.lang.InterruptedException
# 	at java.lang.Object.wait(Native Method)
# 	at java.lang.Thread.join(Thread.java:1252)
# ...

# %%
# 8 slave - Encyclopaedia Britannica
# !time hadoop jar /usr/lib/hadoop-mapreduce/hadoop-streaming.jar -input "Encyclopaedia Britannica"/* -output resultBritanica8 -mapper 'python mapper.py' -reducer 'python reducer.py' -file /home/hadoop/mapper.py  -file /home/hadoop/reducer.py
# Out:
# 21/04/24 16:44:31 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/home/hadoop/mapper.py, /home/hadoop/reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.10.1-amzn-1.jar] /tmp/streamjob5512507838337352250.jar tmpDir=null
# 21/04/24 16:44:32 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:44:32 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:44:32 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:44:32 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:44:33 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# ...

# %%
# 8 slave - Wikipedia
# !time hadoop jar /usr/lib/hadoop-mapreduce/hadoop-streaming.jar -input Wikipedia/* -output resultWiki8 -mapper 'python mapper.py' -reducer 'python reducer.py' -file /home/hadoop/mapper.py  -file /home/hadoop/reducer.py
# Out:
# 21/04/24 16:45:57 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/home/hadoop/mapper.py, /home/hadoop/reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.10.1-amzn-1.jar] /tmp/streamjob6125905580224733385.jar tmpDir=null
# 21/04/24 16:45:58 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:45:58 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:45:58 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 16:45:58 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 16:45:59 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# ...

# %%
#8 slaves 30 reducers

# !time hadoop jar /usr/lib/hadoop-mapreduce/hadoop-streaming.jar -D mapred.reduce.tasks=30 -input Wikipedia/* -output resultWiki833 -mapper 'python mapper.py' -reducer 'python reducer.py' -file /home/hadoop/mapper.py  -file /home/hadoop/reducer.py
# Out:
# 21/04/24 17:02:33 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/home/hadoop/mapper.py, /home/hadoop/reducer.py] [/usr/lib/hadoop/hadoop-streaming-2.10.1-amzn-1.jar] /tmp/streamjob5337183077273278155.jar tmpDir=null
# 21/04/24 17:02:34 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 17:02:34 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 17:02:34 INFO client.RMProxy: Connecting to ResourceManager at ip-172-31-69-228.ec2.internal/172.31.69.228:8032
# 21/04/24 17:02:34 INFO client.AHSProxy: Connecting to Application History server at ip-172-31-69-228.ec2.internal/172.31.69.228:10200
# 21/04/24 17:02:35 INFO lzo.GPLNativeCodeLoader: Loaded native gpl library
# ...
